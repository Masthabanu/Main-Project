# %% [markdown]
# # **Project Title**
#
# Student Academic Performance & Improvement Analysis Using Python

# %% [markdown]
# # **Objective(Problem statement)**
#
# 1. To analyse student academic performance and improvement trends using Python and Power BI.
#
# 2. To identify key factors affecting student grades, academic progress, and educational outcomes through data analytics.
#
# 3. To perform data cleaning, preprocessing, and transformation on real-world student performance datasets using Python.
#
# 4. To evaluate academic indicators such as attendance, study hours, motivation, parental involvement, and professor quality to generate meaningful insights.
#
# 5. To analyse student improvement patterns from Previous Grade to Current Grade and measure overall improvement rates.
#
# 6. To create interactive dashboards and visualizations that support data-driven decision-making in educational institutions.

# %% [markdown]
# # **Outcome**
#
# The project helps identify key patterns, trends, and academic insights from student performance data through data analytics and visualization. The analysis supports data-driven decision-making by providing meaningful and evidence-based insights into student academic performance, improvement trends, attendance, study behaviour, motivation, parental involvement, and factors influencing educational success.

# %% [markdown]
# # **Domain**
# Education

# %% [markdown]
# #**Dataset Information**
#
# **Source:** https://raw.githubusercontent.com/Masthabanu/Main-Project/refs/heads/main/Factors_affecting_university_student_grades_dataset.csv
#
# **Year / Timeline:** May 2024
#
# **Dataset Column/features Description:**
#
# * **Age:** The age of the student.
# * **Gender:** The gender of the student (M for Male, F for Female).
# * **Parental_Education:** The highest level of education attained by the student's parents.
# * **Family_Income:** The family income level.
# * **Previous_Grades:** The student's previous academic performance (A, B, or C grades).
# * **Attendance:** The percentage of attendance in classes.
# * **Class_Participation:** The level of participation in class activities (Low, Medium, or High).
# * **Study_Hours:** The average number of study hours per week.
# * **Major:** The student's major or field of study.
# * **School_Type:** The type of University attended (Public or Private).
# * **Financial_Status:** The financial status of the student (Low, Medium, or High).
# * **Parental_Involvement:** The level of parental involvement in the student's education (Low, Medium, or High).
# * **Educational_Resources:** Availability of educational resources at home (Yes or No).
# * **Motivation:** The level of motivation towards studies (Low, Medium, or High).
# * **Self_Esteem:** The level of self-esteem (Low, Medium, or High).
# * **Stress_Levels:** The level of stress experienced by the student (Low, Medium, or High).
# * **School_Environment:** Perception of the school environment (Negative, Neutral, or Positive).
# * **Professor_Quality:** The quality of professors (Low, Medium, or High).
# * **Class_Size:** The size of the class.
# * **Sleep_Patterns:** Average hours of sleep per day.
# * **Screen_Time:** Hours spent on screen-based activities per day.
# * **Lack_of_Interest:** Level of interest in academics (Low, Medium, or High).
# * **Time_Wasted_on_Social_Media:** Time spent on social media platforms.
# * **Grades:** The final grades achieved by the student (A, B, or C).

# %% [markdown]
# # **Note For Kind of Analysis to be done**
#
# Type of Analysis
#
# • Descriptive Analysis (Summarizing the Dataset)
#
# • Diagnostic Analysis (Finding Reasons Behind Patterns)
#
# <u> Descriptive Analysis </u>
#
# • To summarize the overall student population and academic performance trends in the dataset.
#
# • To analyse key academic indicators such as average attendance percentage and average study hours.
#
# • To examine the distribution of Previous Grades and Current Grades among students.
#
# • To identify the most common academic grades, majors, and motivation levels within the student population.
#
# • To measure student improvement patterns from Previous Grade to Current Grade.
#
# • To analyse the distribution of students across gender, majors, and educational factors.
#
# <u> Diagnostic Analysis </u>
#
# • To identify attendance and study habits as factors influencing academic performance.
#
# • To analyse the impact of motivation levels on student academic outcomes.
#
# • To investigate the role of parental involvement in student improvement and academic success.
#
# • To compare academic performance across different majors to identify variations in student achievement.
#
# • To evaluate the relationship between previous academic performance and current grades.
#
# • To analyse factors contributing to student improvement, including motivation, class participation, parental involvement, and professor quality.

# %% [markdown]
# # Stages for DA Project

# %% [markdown]
# ## Stage 1 – Problem Definition and Dataset Selection
#
#
# **NOTE : THINGS TO BE COMPLETED**
#
# * Define the business problem and expected outcome
#
# * Choose dataset and explain its source, size, and features
#
# * Import libraries, load dataset
#
# * Dataset description (rows, columns, features)
#
# * Initial EDA (head, info, describe, shape, null checks, duplicate check)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/My Drive/DA Main Project/Factors_affecting_university_student_grades_dataset.csv')

# %%
df.size
# Out:
# 241536

# %%
df.head()
# Out:
#     Age Gender Parental_Education Family_Income Previous_Grades  Attendance  \
# 0  22.0      F            College         50000               A        81.0
# 1  21.0      M                NaN         60000               A         NaN
# 2  19.0      M            College         75000               C        93.0
# 3  21.0      M            College         60000               A        86.0
# 4  19.0    NaN                NaN         40000             NaN        89.0
#
#   Class_Participation  Study_Hours     Major School_Type  ... Self_Esteem  \
# 0              Medium          8.0       Law     Private  ...         Low
# 1              Medium         12.0       Law      Public  ...        High
# 2              Medium         12.0       Law     Private  ...         Low
# 3                 Low         15.0  Business      Public  ...      Medium
# 4                High         15.0  Medicine         NaN  ...         NaN
#
# ...

# %%
df.tail()
# Out:
#         Age Gender Parental_Education Family_Income Previous_Grades  \
# 10059  20.0    NaN       Some College         75000               A
# 10060  19.0      M            College           NaN               B
# 10061  20.0      M                NaN         30000               B
# 10062  21.0      F            College         50000               B
# 10063  18.0      F       Some College         30000               A
#
#        Attendance Class_Participation  Study_Hours        Major School_Type  \
# 10059        78.0                 NaN         16.0          Law     Private
# 10060         NaN              Medium          5.0      Science      Public
# 10061        97.0              Medium          7.0  Engineering      Public
# 10062        75.0              Medium         15.0          NaN      Public
# 10063        80.0                 Low         16.0          Law      Public
#
#        ... Self_Esteem Stress_Levels School_Environment Professor_Quality  \
# ...

# %%
df.shape
# Out:
# (10064, 24)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Parental_Education', 'Family_Income',
#        'Previous_Grades', 'Attendance', 'Class_Participation', 'Study_Hours',
#        'Major', 'School_Type', 'Financial_Status', 'Parental_Involvement',
#        'Educational_Resources', 'Motivation', 'Self_Esteem', 'Stress_Levels',
#        'School_Environment', 'Professor_Quality', 'Class_Size',
#        'Sleep_Patterns', 'Screen_Time', 'Lack_of_Interest',
#        'Time_Wasted_on_Social_Media', 'Grades'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10064 entries, 0 to 10063
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          9099 non-null   float64
#  1   Gender                       9085 non-null   object
#  2   Parental_Education           9102 non-null   object
#  3   Family_Income                9097 non-null   object
#  4   Previous_Grades              9120 non-null   object
#  5   Attendance                   9060 non-null   float64
#  6   Class_Participation          9098 non-null   object
#  7   Study_Hours                  9073 non-null   float64
#  8   Major                        9136 non-null   object
#  9   School_Type                  9115 non-null   object
#  10  Financial_Status             9129 non-null   object
#  11  Parental_Involvement         9118 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age   Attendance  Study_Hours   Class_Size  Sleep_Patterns  \
# count  9099.000000  9060.000000  9073.000000  9114.000000     9048.000000
# mean     19.996703    84.908499    12.467761    60.238754        6.538904
# std       1.406885     8.985221     4.613845    23.337209        1.720632
# min      18.000000    70.000000     5.000000    20.000000        4.000000
# 25%      19.000000    77.000000     9.000000    40.000000        5.000000
# 50%      20.000000    85.000000    12.000000    61.000000        7.000000
# 75%      21.000000    93.000000    16.000000    80.000000        8.000000
# max      22.000000   100.000000    20.000000   100.000000        9.000000
#
#        Screen_Time  Time_Wasted_on_Social_Media
# count  9120.000000                  9137.000000
# mean      6.031469                     3.489329
# std       2.597880                     1.704057
# min       2.000000                     1.000000
# 25%       4.000000                     2.000000
# ...

# %%
df.dtypes
# Out:
# Age                            float64
# Gender                          object
# Parental_Education              object
# Family_Income                   object
# Previous_Grades                 object
# Attendance                     float64
# Class_Participation             object
# Study_Hours                    float64
# Major                           object
# School_Type                     object
# Financial_Status                object
# Parental_Involvement            object
# Educational_Resources           object
# Motivation                      object
# Self_Esteem                     object
# Stress_Levels                   object
# School_Environment              object
# Professor_Quality               object
# Class_Size                     float64
# Sleep_Patterns                 float64
# Screen_Time                    float64
# Lack_of_Interest                object
# Time_Wasted_on_Social_Media    float64
# Grades                          object
# dtype: object

# %%
df.nunique()
# Out:
# Age                             5
# Gender                          2
# Parental_Education              4
# Family_Income                   6
# Previous_Grades                 3
# Attendance                     31
# Class_Participation             3
# Study_Hours                    16
# Major                           6
# School_Type                     2
# Financial_Status                3
# Parental_Involvement            3
# Educational_Resources           2
# Motivation                      3
# Self_Esteem                     3
# Stress_Levels                   3
# School_Environment              3
# Professor_Quality               3
# Class_Size                     81
# Sleep_Patterns                  6
# Screen_Time                     9
# Lack_of_Interest                3
# Time_Wasted_on_Social_Media     6
# Grades                          3
# dtype: int64

# %%
df.isna().sum()
# Out:
# Age                             965
# Gender                          979
# Parental_Education              962
# Family_Income                   967
# Previous_Grades                 944
# Attendance                     1004
# Class_Participation             966
# Study_Hours                     991
# Major                           928
# School_Type                     949
# Financial_Status                935
# Parental_Involvement            946
# Educational_Resources           935
# Motivation                      970
# Self_Esteem                     912
# Stress_Levels                   919
# School_Environment              958
# Professor_Quality               950
# Class_Size                      950
# Sleep_Patterns                 1016
# Screen_Time                     944
# Lack_of_Interest                928
# Time_Wasted_on_Social_Media     927
# Grades                         1040
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Stage 2 – Data Cleaning and Pre-processing
#
# - Handle missing values (impute or drop)
#
# - Handle duplicates
# - column name rename or dropping unwanted columns if required
#
# - Treat outliers if required
#
# - Check skewness and apply transformations
#
# - Convert data types if needed
#
# - Feature transformations (date parts, derived fields if required for analysis)

# %%
# Fill missing values in the Age column using the mean value

df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
# Change the datatype of age column:

df['Age'] = df['Age'].astype(int)

# %%
# Check the number of students in each Gender

df['Gender'].value_counts().reset_index()
# Out:
#   Gender  count
# 0      F   4557
# 1      M   4528

# %%
# Fill missing values in the Gender column using mode

df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])

# %%
# Display the updated distribution after filling missing values

df['Gender'].value_counts().reset_index()
# Out:
#   Gender  count
# 0      F   5536
# 1      M   4528

# %%
# Check the number of students in each Parental education

df['Parental_Education'].value_counts().reset_index()
# Out:
#   Parental_Education  count
# 0       Some College   2323
# 1           Graduate   2277
# 2            College   2261
# 3        High School   2241

# %%
# Fill missing values in the Parental_Education column using mode

df['Parental_Education'] = df['Parental_Education'].fillna(df['Parental_Education'].mode()[0])

# %%
# Display the updated distribution after filling missing values

df['Parental_Education'].value_counts().reset_index()
# Out:
#   Parental_Education  count
# 0       Some College   3285
# 1           Graduate   2277
# 2            College   2261
# 3        High School   2241

# %%
# Convert Family_Income column to numeric format and replace invalid values with NaN

df['Family_Income'] = pd.to_numeric(df['Family_Income'],errors = 'coerce')

# %%
# Fill missing values in the Family_Income column using mean

df['Family_Income'] = df['Family_Income'].fillna(df['Family_Income'].mean())

# %%
# Check the number of students in each Previous Grade category

df['Previous_Grades'].value_counts().reset_index()
# Out:
#   Previous_Grades  count
# 0               C   3097
# 1               A   3036
# 2               B   2987

# %%
# Fill missing values in the Previous grade column using mode

df['Previous_Grades'] = df['Previous_Grades'].fillna(df['Previous_Grades'].mode()[0])

# %%
# Display the updated distribution after filling missing values

df['Previous_Grades'].value_counts().reset_index()
# Out:
#   Previous_Grades  count
# 0               C   4041
# 1               A   3036
# 2               B   2987

# %%
# Fill missing values in the Family_Income column using mean

df['Attendance'] = df['Attendance'].fillna(df['Attendance'].mean())

# %%
# Change the datatype of Attendance column

df['Attendance'] = df['Attendance'].astype(int)

# %%
# Check the number of students in each Class participation

df['Class_Participation'].value_counts().reset_index()
# Out:
#   Class_Participation  count
# 0              Medium   3047
# 1                 Low   3026
# 2                High   3025

# %%
# Fill missing values in Class participation using the mode value

df['Class_Participation'] = df['Class_Participation'].fillna(df['Class_Participation'].mode()[0])

# %%
# Display the updated distribution after filling missing values

df['Class_Participation'].value_counts().reset_index()
# Out:
#   Class_Participation  count
# 0              Medium   4013
# 1                 Low   3026
# 2                High   3025

# %%
# Fill missing values in Study hours column using the mean value

df['Study_Hours'] = df['Study_Hours'].fillna(df['Study_Hours'].mean())

# %%
# Change the datatype of Study hours column

df['Study_Hours'] = df['Study_Hours'].astype(int)

# %%
# Check the number of students in each Major

df['Major'].value_counts().reset_index()
# Out:
#          Major  count
# 0     Business   1576
# 1          Law   1569
# 2         Arts   1516
# 3      Science   1507
# 4     Medicine   1494
# 5  Engineering   1474

# %%
# Fill missing values in Major using the mode value

df['Major'] = df['Major'].fillna(df['Major'].mode()[0])

# %%
# Display the updated distribution after filling missing values

df['Major'].value_counts().reset_index()
# Out:
#          Major  count
# 0     Business   2504
# 1          Law   1569
# 2         Arts   1516
# 3      Science   1507
# 4     Medicine   1494
# 5  Engineering   1474

# %%
# Check the number of students in each School type

df['School_Type'].value_counts().reset_index()
# Out:
#   School_Type  count
# 0      Public   4580
# 1     Private   4535

# %%
# Fill missing values in School type using the mode value

df['School_Type'] = df['School_Type'].fillna(df['School_Type'].mode()[0])

# %%
# Display the updated distribution after filling missing values

df['School_Type'].value_counts().reset_index()
# Out:
#   School_Type  count
# 0      Public   5529
# 1     Private   4535

# %%
# Check the number of students in each Finanicial status

df['Financial_Status'].value_counts().reset_index()
# Out:
#   Financial_Status  count
# 0              Low   3068
# 1           Medium   3038
# 2             High   3023

# %%
# Fill missing values in Financial status using the mode value

df['Financial_Status'] = df['Financial_Status'].fillna(df['Financial_Status'].mode()[0])

# %%
# Display the updated distribution after filling missing values

df['Financial_Status'].value_counts().reset_index()
# Out:
#   Financial_Status  count
# 0              Low   4003
# 1           Medium   3038
# 2             High   3023

# %%
# Check the number of students in each Parental involvement

df['Parental_Involvement'].value_counts().reset_index()
# Out:
#   Parental_Involvement  count
# 0                 High   3117
# 1               Medium   3057
# 2                  Low   2944

# %%
# Fill missing values in mode value

df['Parental_Involvement'] = df['Parental_Involvement'].fillna(df['Parental_Involvement'].mode()[0])

# %%
# Display the updated distribution after filling missing values

df['Parental_Involvement'].value_counts().reset_index()
# Out:
#   Parental_Involvement  count
# 0                 High   4063
# 1               Medium   3057
# 2                  Low   2944

# %%
# Check the number of students in each Educational resources

df['Educational_Resources'].value_counts().reset_index()
# Out:
#   Educational_Resources  count
# 0                   Yes   4634
# 1                    No   4495

# %%
# Fill missing values using mode value

df['Educational_Resources'] = df['Educational_Resources'].fillna(df['Educational_Resources'].mode()[0])

# %%
# Display the updated distribution after filling missing values

df['Educational_Resources'].value_counts().reset_index()
# Out:
#   Educational_Resources  count
# 0                   Yes   5569
# 1                    No   4495

# %%
# Check the number of students in each Motivation level

df['Motivation'].value_counts().reset_index()
# Out:
#   Motivation  count
# 0       High   3062
# 1     Medium   3031
# 2        Low   3001

# %%
# Fill missing values using mode value

df['Motivation'] = df['Motivation'].fillna(df['Motivation'].mode()[0])

# %%
# Display the updated distribution after filling missing values

df['Motivation'].value_counts().reset_index()
# Out:
#   Motivation  count
# 0       High   4032
# 1     Medium   3031
# 2        Low   3001

# %%
# Check the number of students in each Seld esteem

df['Self_Esteem'].value_counts().reset_index()
# Out:
#   Self_Esteem  count
# 0         Low   3106
# 1        High   3041
# 2      Medium   3005

# %%
# Fill missing values using mode value

df['Self_Esteem'] = df['Self_Esteem'].fillna(df['Self_Esteem'].mode()[0])

# %%
# Display the updated distribution after filling missing values

df['Self_Esteem'].value_counts().reset_index()
# Out:
#   Self_Esteem  count
# 0         Low   4018
# 1        High   3041
# 2      Medium   3005

# %%
# Check the number of students in each Stress levels

df['Stress_Levels'].value_counts().reset_index()
# Out:
#   Stress_Levels  count
# 0           Low   3087
# 1        Medium   3059
# 2          High   2999

# %%
# Fill missing values using mode value

df['Stress_Levels'] = df['Stress_Levels'].fillna(df['Stress_Levels'].mode()[0])

# %%
# Display the updated distribution after filling missing values

df['Stress_Levels'].value_counts().reset_index()
# Out:
#   Stress_Levels  count
# 0           Low   4006
# 1        Medium   3059
# 2          High   2999

# %%
# Check the number of students in each School environment

df['School_Environment'].value_counts().reset_index()
# Out:
#   School_Environment  count
# 0            Neutral   3083
# 1           Negative   3043
# 2           Positive   2980

# %%
# Fill missing values using mode value

df['School_Environment'] = df['School_Environment'].fillna(df['School_Environment'].mode()[0])

# %%
# Display the updated distribution after filling missing values

df['School_Environment'].value_counts().reset_index()
# Out:
#   School_Environment  count
# 0            Neutral   4041
# 1           Negative   3043
# 2           Positive   2980

# %%
# Check the number of students in each Professor quality

df['Professor_Quality'].value_counts().reset_index()
# Out:
#   Professor_Quality  count
# 0               Low   3081
# 1            Medium   3034
# 2              High   2999

# %%
# Fill missing values using mode value

df['Professor_Quality'] = df['Professor_Quality'].fillna(df['Professor_Quality'].mode()[0])

# %%
# Display the updated distribution after filling missing values

df['Professor_Quality'].value_counts().reset_index()
# Out:
#   Professor_Quality  count
# 0               Low   4031
# 1            Medium   3034
# 2              High   2999

# %%
# Fill missing values using mean value

df['Class_Size'] = df['Class_Size'].fillna(df['Class_Size'].mean())

# %%
# Change the datatype of Class size column

df['Class_Size'] = df['Class_Size'].astype(int)

# %%
# Fill missing values using mean value

df['Sleep_Patterns'] = df['Sleep_Patterns'].fillna(df['Sleep_Patterns'].mean())

# %%
# Change the datatype of Sleep patterns column

df['Sleep_Patterns'] = df['Sleep_Patterns'].astype(int)

# %%
# Fill missing values using mean value

df['Screen_Time'] = df['Screen_Time'].fillna(df['Screen_Time'].mean())

# %%
# Change the datatype of Screen time column

df['Screen_Time'] = df['Screen_Time'].astype(int)

# %%
# Check the number of students in each Lack of interest

df['Lack_of_Interest'].value_counts().reset_index()
# Out:
#   Lack_of_Interest  count
# 0             High   3082
# 1           Medium   3050
# 2              Low   3004

# %%
# Fill missing values in Lack of interest using the mode value

df['Lack_of_Interest'] = df['Lack_of_Interest'].fillna(df['Lack_of_Interest'].mode()[0])

# %%
# Display the updated distribution after filling missing values

df['Lack_of_Interest'].value_counts().reset_index()
# Out:
#   Lack_of_Interest  count
# 0             High   4010
# 1           Medium   3050
# 2              Low   3004

# %%
# Fill missing values using the mean value

df['Time_Wasted_on_Social_Media'] =df['Time_Wasted_on_Social_Media'].fillna(df['Time_Wasted_on_Social_Media'].mean())

# %%
# Change the datatype of Time_Wasted_on_Social_Media column

df['Time_Wasted_on_Social_Media'] =df['Time_Wasted_on_Social_Media'].astype(int)

# %%
# Check the number of students in each grades

df['Grades'].value_counts().reset_index()
# Out:
#   Grades  count
# 0      B   3038
# 1      C   3010
# 2      A   2976

# %%
# Fill missing values in Grades using the mode value

df['Grades'] = df['Grades'].fillna(df['Grades'].mode()[0])

# %%
# Display the updated distribution after filling missing values

df['Grades'].value_counts().reset_index()
# Out:
#   Grades  count
# 0      B   4078
# 1      C   3010
# 2      A   2976

# %%
df
# Out:
#        Age Gender Parental_Education  Family_Income Previous_Grades  \
# 0       22      F            College   50000.000000               A
# 1       21      M       Some College   60000.000000               A
# 2       19      M            College   75000.000000               C
# 3       21      M            College   60000.000000               A
# 4       19      F       Some College   40000.000000               C
# ...    ...    ...                ...            ...             ...
# 10059   20      F       Some College   75000.000000               A
# 10060   19      M            College   50953.166227               B
# 10061   20      M       Some College   30000.000000               B
# 10062   21      F            College   50000.000000               B
# 10063   18      F       Some College   30000.000000               A
#
#        Attendance Class_Participation  Study_Hours        Major School_Type  \
# ...

# %%
df.isna().sum()
# Out:
# Age                            0
# Gender                         0
# Parental_Education             0
# Family_Income                  0
# Previous_Grades                0
# Attendance                     0
# Class_Participation            0
# Study_Hours                    0
# Major                          0
# School_Type                    0
# Financial_Status               0
# Parental_Involvement           0
# Educational_Resources          0
# Motivation                     0
# Self_Esteem                    0
# Stress_Levels                  0
# School_Environment             0
# Professor_Quality              0
# Class_Size                     0
# Sleep_Patterns                 0
# Screen_Time                    0
# Lack_of_Interest               0
# Time_Wasted_on_Social_Media    0
# Grades                         0
# dtype: int64

# %% [markdown]
# ## Stage 3 – EDA and Visualizations
#
# Univariate Analysis → distribution of single variables (countplot, histogram, boxplot)
#
# Bivariate Analysis → relation between two variables (scatterplot, barplot, correlation heatmap)
#
# Multivariate Analysis → relation among 3+ variables (pairplot, grouped analysis, pivot tables, advanced plots)
#
# Interpretation MUST with every visualization
#
# Focus on business story not just charts
#
# Each chart must be in seperate cells.

# %%
# Previous Grade Distribution

prev_grade = df['Previous_Grades'].value_counts()

plt.figure(figsize=(6,4))

plt.pie(
    prev_grade,
    labels = prev_grade.index,
    autopct='%1.1f%%',
    explode = [0.1,0,0],
    shadow = True,
    colors = ['#2E8B57', '#4682B4', '#FF8C00'])

plt.title("Previous Grade Distribution")
plt.show()

# %% [markdown]
# # Insights
# * Previous Grade C is the largest group with 40.2% of students.
# * Previous Grade A and B students each contribute approximately 30% of the student population.
# * The chart shows that many students started with lower academic performance.
#
# # Business Insight
# * University can give extra support to students with Previous Grade C.
# * Teachers can identify students who may need additional guidance.
# * Understanding previous grades helps improve academic planning and student support programs.
# * Educational institutions can use this information to improve student performance and success.

# %% [markdown]
# # Explain the chart
#
#    This chart shows how students were distributed based on their previous grades (A, B, and C).
#
# # What is it saying?
# * Grade C has the highest number of students (40.2%).
# * Grade A has about 30.2% of students.
# * Grade B has about 29.7% of students.
# * Most students belonged to Grade C before their current performance.
# * Grade A and Grade B students are almost equal in number.
#
# # Features used
# Feature Used: Previous_Grades
#
# Visualization: Pie Chart
#
# # What are we showing?
# * Number of students in each previous grade category.
# * Percentage of students in Grades A, B, and C.
# * Students' academic background before their current grades.

# %%
# Grade Distribution

grade_counts = df['Grades'].value_counts()

plt.figure(figsize=(6,4))

plt.pie(
    grade_counts,
    labels = grade_counts.index,
    autopct = '%1.1f%%',
    explode = [0.1,0,0],
    shadow = True,
    colors = ['#2E8B57', '#4682B4', '#FF8C00'])

plt.title('Grade Distribution')
plt.show()

# %% [markdown]
# # Insights
# * Grade B has the highest number of students with 40.5%.
# * Grade C has about 29.9% of students.
# * Grade A has about 29.6% of students.
# * Most students are currently performing at the Grade B level, showing average to good academic performance.
# * The number of Grade A and Grade C students is almost the same, with only a small difference.
#
# # Business Insight
# * Educational institutions can focus on helping Grade B students to move towards Grade A.
# * Additional support can be provided to Grade C students to improve their academic performance.
# * Understanding grade distribution helps to plan academic support programs more effectively.
# * The results can be used to monitor overall student performance and educational outcomes.

# %% [markdown]
# # Explain the chart
# This chart shows how students are distributed based on their current grades (A, B, and C).
#
# # What is it saying?
# * Grade B has the highest number of students (40.5%).
# * Grade C accounts for 29.9% of students.
# * Grade A accounts for 29.6% of students.
# * Most students currently belong to Grade B.
# * Grade A and Grade C students are almost equal in number.
# * The distribution shows that many students are performing at a moderate academic level.
#
# # Features used
# Feature Used: Grades
#
# Visualization: Pie Chart
#
# # What are we showing?
# * Distribution of students by current grade.
# * Percentage of students in Grades A, B, and C.
# * Overall academic performance of students.

# %%
# Distribution of previous grade vs current grade

plt.figure(figsize=(8,5))

sns.countplot(
    x='Previous_Grades',
    hue='Grades',
    data = df
    )

plt.title('Previous Grades vs Current Grades')
plt.xlabel('Previous grade')
plt.ylabel('Total Students')
plt.show()

# %% [markdown]
# # Insights
# * Students with Previous Grade C have the highest population compared to Previous Grade A and Previous Grade B.
# * 1,629 students moved from Previous Grade C to Current Grade B, which is the largest group in the chart.
# * Previous Grade C students show a noticeable improvement, as many students are now achieving Grade B.
# * Students with Previous Grade A and Previous Grade B also have strong representation in Current Grade B.
# * The improvement from Previous Grade C to Current Grade B indicates positive academic progress among a large number of students.
#
# # Business Insight
# * Students with Previous Grade C should continue receiving academic support because many have successfully improved to Grade B.
# * Educational institutions can study the factors behind this improvement and apply similar strategies to other students.

# %% [markdown]
# # Explain the chart
# This chart compares students previous grades with their current grades and shows how academic performance has changed.
#
# # What is it saying?
# * Students with Previous Grade C form the largest group in the dataset.
# * Among students who previously had Grade C, the highest number are now in Grade B.
# * Students with Previous Grade A and Previous Grade B also have a high number of students currently in Grade B.
# * Grade B is the most common current grade across all previous grade categories.
# * The chart shows that many students have moved from lower academic performance towards a better grade.
#
# # Features used
# X-axis : Previous_Grades
#
# Y-axis : Total Students
#
# Legend : Current Grades (A, B, C)
#
# Visualization : Seaborn Countplot
#
# # What are we showing?
# * Relationship between previous grades and current grades.
# * Student improvement and performance changes.
# * Distribution of current grades within each previous grade category.

# %%
# Grade vs gender

plt.figure(figsize=(8,5))

sns.countplot(
    x='Gender',
    hue='Grades',
    data = df
    )

plt.title('Grade Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Total Student')
plt.show()

# %% [markdown]
# # Insights
# * Female students show higher participation across all grade categories compared to male students.
# * Grade B is the most common grade for both male and female students, indicating that most students are performing at a moderate academic level.
# * Both genders follow a similar performance pattern, with Grade B being more common than Grade A and Grade C.
#
# # Business Insight
# * Educational institutions can design improvement programs that benefit both genders rather than focusing on only one group.
# * Since female students represent a larger portion of the dataset, their performance trends have a significant impact on overall academic results.
# * Monitoring grade distribution by gender helps institutions ensure equal academic opportunities and support for all students.

# %% [markdown]
# # Explain the chart
# This chart shows how grades (A, B, and C) are distributed among male and female students.
#
# # What is it saying?
# * Female students have a higher number of students in all grade categories compared to male students.
# * Grade B is the most common grade for both male and female students.
# * The number of female students achieving Grade B is the highest among all groups.
# * Grade A and Grade C are also more common among female students than male students.
# * Both genders show a similar performance pattern, with Grade B being the dominant grade.
#
# # Features used
# X-axis : Gender
#
# Y-axis : Total Students
#
# Legend : Grades (A, B, C)
#
# Visualization : Seaborn Countplot
#
# # What are we showing?
# * Distribution of grades among male and female students.
# * Comparison of academic performance across genders.
# * Most common grade achieved by each gender.

# %%
# Student Distribution by Major

major_count = df['Major'].value_counts()

plt.figure(figsize=(8,5))

plt.barh(
    major_count.index,
    major_count.values,
    color='#4682B4',
    edgecolor='black')

plt.title('Student Distribution by Major')
plt.xlabel('Number of Students')
plt.ylabel('Major')

plt.show()

# %% [markdown]
# # Insights
# * Business is the most popular major among students in the dataset.
# Law also has a strong student population compared to other majors.
# * Arts, Science, Medicine, and Engineering show nearly equal levels of student enrollment.
# * The distribution indicates that students have diverse academic interests across multiple fields.
# * The large student population in Business suggests a higher preference for business-related studies.
# * No major shows an extremely low enrollment level, indicating balanced representation across academic disciplines.
#
# # Business Insight
# * Majors with higher enrollment may require additional classrooms, professors, and academic support services.
# * Understanding major-wise student distribution helps institutions plan future academic programs more effectively.
# * The analysis helps identify popular fields of study and areas where institutions can focus their educational investments.

# %% [markdown]
# # Explain the chart
# This chart shows how students are distributed across different academic majors.
#
# # What is it saying?
# * Business has the highest number of students compared to all other majors.
# * Law has the second-highest student population.
# Arts, Science, Medicine, and Engineering have very similar student counts.
# * Student enrollment is not equally distributed across all majors.
# * Some majors attract more students than others.
#
# # Features used
# Y-axis : Major
#
# X-axis : Number of Students
#
# Visualization : Horizontal Bar Chart
#
# # What are we showing?
# * Distribution of students across different majors.
# * Most and least popular academic majors.
# * Student enrollment patterns by field of study.

# %%
# Motivation Distribution

motivation = df['Motivation'].value_counts()

plt.figure(figsize=(6,4))

plt.pie(
    motivation,
    labels = motivation.index,
    autopct='%1.1f%%',
    explode = [0.1,0,0],
    shadow = True,
    colors = ['#2E8B57', '#4682B4', '#FF8C00']
    )

plt.title("Motivation Distribution")
plt.show()

# %% [markdown]
# # Insights
# * High motivation is the dominant category, indicating that many students are interested and engaged in their studies.
# * Medium and Low motivation levels are very close to each other, suggesting a balanced distribution among less motivated students.
# * The majority of students have at least a moderate level of motivation towards academics.
# * The chart suggests that students with higher motivation may have a greater chance of achieving better academic outcomes.
#
# # Business Insight
# * Educational institutions can develop programs to maintain and strengthen student motivation.
# * Students with low motivation can be identified for mentoring, counselling, and academic support.
# * Understanding motivation patterns helps educators to create strategies that improve student engagement and learning outcomes.
# * Improving student motivation can contribute to better academic performance and overall educational success.

# %% [markdown]
# # Explain the chart
# This chart shows the distribution of students based on their motivation levels (High, Medium, and Low).
#
# # What is it saying?
# * High motivation is the most common category among students.
# * Medium and Low motivation levels have almost equal representation.
# * A large portion of students are motivated towards their studies.
# * Motivation levels vary across students, showing different levels of academic engagement.
#
# # Features used
# Feature Used : Motivation
#
# Visualization : Pie Chart
#
# # What are we showing?
# * Distribution of students by motivation level.
# * Percentage of students with High, Medium, and Low motivation.
# * Overall motivation patterns within the student population.

# %%
# Parental Involvement Distribution

parent_involve = df['Parental_Involvement'].value_counts()

plt.figure(figsize=(8,5))
colors = ['#2E8B57', '#4682B4', '#FF8C00']

plt.bar(
    parent_involve.index,
    parent_involve.values,
    color = colors
    )

plt.title('Parental Involvement Distribution')
plt.xlabel('Parental Involvement')
plt.ylabel('Number of Students')

plt.show()

# %% [markdown]
# # Insights
# * High parental involvement is the most common category among students.
# * Medium and Low parental involvement show only a small difference in their distribution.
# * A large number of students receive strong support and guidance from their parents.
# * The chart indicates that parental involvement is generally positive for most students.
# Students with medium and low parental involvement may require additional academic support.
# * The distribution suggests that parental engagement varies across students but remains an important factor in education.
#
# # Business Insight
# * Schools and universities can encourage stronger parent-student engagement to support academic success.
# * Students with medium and low parental involvement may benefit from additional mentoring and academic guidance.
# * Understanding parental involvement patterns helps educators design better student support programs.
# * Educational institutions can work with parents to improve student motivation, participation, and overall academic performance.

# %% [markdown]
# # Explain the chart
# This chart shows the distribution of students based on the level of parental involvement in their education (High, Medium, and Low).
#
# # What is it saying?
# * High parental involvement is the most common category.
# * Both Medium and Low parental involvement show a small difference.
# * Many students receive active support and involvement from their parents.
# * Parental involvement levels vary among students.
#
# # Features used
# Feature Used : Parental_Involvement
#
# Visualization : Bar Chart
#
# # What are we showing?
# * Distribution of students by parental involvement level.
# * Level of support students receive from their parents.
# * Comparison between High, Medium, and Low involvement groups.

# %%
# Professor Quality Distribution

Prof_quality = df['Professor_Quality'].value_counts()

plt.figure(figsize=(8,5))
colors = ['#2E8B57', '#4682B4', '#FF8C00']

plt.bar(
    Prof_quality.index,
    Prof_quality.values,
    color = colors)

plt.title('Professor Quality Distribution')
plt.xlabel('Professor Quality')
plt.ylabel('Number of Students')

plt.show()

# %% [markdown]
# # Insights
# * Low professor quality is the most common category among students.
# * High and Medium professor quality have a similar distribution.
# * A large number of students rate professor quality as low, which may affect learning experiences.
# * The chart suggests that teaching quality varies across the institution.
# * Students experiencing better professor quality may have greater opportunities for academic success.
# * Professor quality appears to be an important factor that can influence student engagement and performance.
#
# # Business Insight
# * Educational institutions should focus on improving teaching quality through faculty development programs.
# * Student feedback can be used to identify areas where professors need additional support or training.
# * Improving professor quality can lead to better student satisfaction and academic outcomes.
# * Regular monitoring of teaching quality helps institutions maintain effective learning environments.

# %% [markdown]
# # Explain the chart
# This chart shows the distribution of students based on professor quality (High, Medium, and Low).
#
# # What is it saying?
# * Students have different opinions about the quality of professors.
# * Most students rate professor quality as Low.
# * Medium and High professor quality categories have almost similar distribution.
# * A large number of students believe that professor quality needs improvement.
# * Only a smaller portion of students rate professor quality as High.
#
# # Features used
# Feature Used : Professor_Quality
#
# Visualization : Bar Chart
#
# # What are we showing?
# * Distribution of students across different professor quality levels.
# * Student perception of teaching quality.
# * Comparison between High, Medium, and Low professor quality categories.

# %%
# School type Distribution

Scl_type = df['School_Type'].value_counts()

plt.figure(figsize=(6,4))

plt.pie(
    Scl_type,
    labels = Scl_type.index,
    autopct='%1.1f%%',
    colors = ['#4682B4', '#2E8B57']
    )

plt.title("School type Distribution")
plt.show()

# %% [markdown]
# # Insights
# * Public institutions have slightly more students than Private institutions.
# * Both Public and Private institutions have a large number of students.
# * The student distribution is nearly balanced between the two institution types.
# * This shows that the dataset includes students from different educational environments.
#
# # Business Insight
# * Educational institutions can compare the academic performance of students from Public and Private institutions.
# * The balanced distribution helps in identifying whether school type influences student performance.
# * Decision-makers can use this analysis to understand student trends across different institution types.

# %% [markdown]
# # Explain the chart
# This chart shows the distribution of students based on the type of institution they attend (Public or Private)
#
# # What is it saying?
# * More students are studying in Public institutions than in Private institutions.
# * Public institutions have 54.9% of students.
# * Private institutions have 45.1% of students.
# * The difference between Public and Private institutions is small.
#
# # Features used
# Feature Used : School_Type
#
# Visualization : Pie Chart
#
# # What are we showing?
# * Distribution of students across Public and Private institutions.
# * Percentage share of each school type.

# %%
# Study Hours Distribution

plt.figure(figsize=(8,5))

plt.boxplot(
    df['Study_Hours'],
    patch_artist=True,
    boxprops=dict(
        facecolor='#90EE90',
        color='darkgreen',
        linewidth=2
    ),
    medianprops=dict(
        color='red',
        linewidth=2
    ),
    whiskerprops=dict(
        color='black',
        linewidth=1.5
    ),
    capprops=dict(
        color='black',
        linewidth=1.5
    ),
    flierprops=dict(
        marker='o',
        markerfacecolor='orange',
        markeredgecolor='black',
        markersize=6
    )
)

plt.title('Study Hours Distribution')
plt.ylabel('Study Hours')

plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks([])
plt.show()

# %% [markdown]
# # Insights
# * Most students maintain a moderate level of study hours.
# * The middle 50% of students study within a relatively consistent range.
# * Study habits differ across students, indicating variation in learning behaviour.
# * No extreme study-hour values are observed, suggesting a balanced dataset.
# * Students generally follow regular study patterns rather than very low or very high study schedules.
#
# # Business Insight
# * Academic support programs can encourage students at the lower end of the study-hour range to improve their study routines.
# * Since study hours vary among students, personalized learning strategies may be more effective than a one-size-fits-all approach.
# * Monitoring study behaviour can help institutions identify students who may require additional academic guidance.
# * Study hours can be used along with attendance, motivation, and class participation to better understand student performance.

# %% [markdown]
# # Explain the chart
# This box plot shows the distribution of students study hours and helps identify the typical study pattern, variation, and spread of study hours.
#
# # What is it saying?
# * The median study time is approximately 12 hours.
# * Most students study between 9 and 16 hours.
# * Study hours range from approximately 5 to 20 hours.
# * There are no significant outliers in the dataset.
# * Study habits vary among students, but most students fall within a moderate study range.
#
# # Features used
# Feature Used : Study_Hours
#
# Visualization : Box Plot
#
# # What are we showing?
# * Distribution of study hours.
# * Median study time.
# * Range of study hours.
# * Variation in student study habits.
# * Presence or absence of outliers.

# %%
# Attendance Distribution

plt.hist(
    df['Attendance'],
    bins=10,
    color='#4682B4',
    edgecolor='black')

plt.title("Attendance Distribution")
plt.xlabel("Attendance")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# # Insights
# * Most students maintain attendance above 80%, indicating regular participation in academic activities.
# * The highest concentration of students is found around the mid-to-high attendance range.
# * Attendance levels are fairly spread across the dataset, showing variation in student attendance behaviour.
# * Only a small portion of students have attendance near the minimum range.
# * Overall attendance levels suggest that students are generally engaged in their academic activities.
#
# # Business Insight
# * Good attendance levels indicate strong student participation in classes.
# * Educational institutions can continue promoting attendance-related policies to maintain academic engagement.
# * Students with lower attendance can be identified and provided with additional support or intervention programs.
# * Monitoring attendance can help institutions identify students who may be at risk of poor academic performance.
# * Attendance remains an important indicator of student involvement and academic commitment.

# %% [markdown]
# # Explain the chart
# This histogram shows how student attendance is distributed across the dataset.
#
# # What is it saying?
# * Most students have attendance levels between 80% and 85%.
# * Student attendance is generally concentrated in the higher attendance range.
# * Very few students have extremely low attendance.
# * Attendance values are distributed across the entire range from approximately 70% to 100%.
# * A large number of students maintain good attendance levels throughout their academic period.
#
# # Features used
# X-axis: Attendance
#
# Y-axis: Number of Students
#
# Visualization: Histogram
#
# # What are we showing?
# * Distribution of student attendance percentages.
# * Attendance patterns among students.
# * Overall attendance behaviour of the student population.

# %% [markdown]
# ## **Steps to Download your cleaned data for dashboard creation using Power BI**

# %%
import pandas as pd
df.to_csv('student_performance_cleaned.csv', index=False)

# %% [markdown]
# ## Stage 4 – Documentation, Insights and Presentation
#
# Show a dashboard aligning all the charts in powerbi by connecting python in PowerBI
#
# Summarize findings in plain English (what do the patterns mean)
#
# Highlight 3–5 key insights (trends, anomalies, correlations)
#
# Provide recommendations for business or decision-making
#
# Explain the FINAL STORY WITH THE DASHBOARD/report
#
# Create a PDF pasting your DASHBOARD, explaining all the above mentioned concepts and submit it

# %% [markdown]
# ![Main_Project_Dashboard1.png](data:image/png;base64,...)

# %% [markdown]
# ![Main_Project_Dashboard2.png](data:image/png;base64,...)

# %% [markdown]
# # your stage 4 pdf Link
# https://drive.google.com/drive/folders/1Xqx6dJHbLWLlXBRd4C0wF9SNSw1iDn8Q?usp=sharing

# %% [markdown]
# ## **Final Overall Insights:**
# * insights from the final dashboard observation on the basics of 4 types of analysis

# %% [markdown]
# **<U>Descriptive Analysis:</u>**
#
# * A total of 10,064 student records were analysed. The average attendance was 84.82%, and students studied an average of 12.42 hours.
# * The dataset contains students from different academic backgrounds, majors, school types, and performance levels.
# * Most students belonged to the Previous Grade C category, showing that a large portion of students had lower academic performance before the current evaluation period.
# * Grade B was the most commonly achieved final grade, indicating that many students moved towards an average academic performance level.
# * Gender-wise grade analysis shows similar performance patterns among male and female students, with Grade B being the dominant grade for both groups.
# * High levels of motivation, parental involvement, and class participation are observed among a large number of students.
# * Attendance levels are generally consistent across students, indicating regular participation in academic activities.
# * Students follow relatively stable study habits, with most students studying within a moderate range of hours.
# * The distribution of professor quality indicates that students have mixed opinions about teaching quality, with a large portion of students rating it as low.
#
#
# **<u>Diagnostic Analysis:</u>**
# * The comparison between previous grades and current grades shows that a significant number of students improved from Grade C to Grade B, indicating positive academic progress.
# * The improvement funnel confirms that many lower-performing students were able to move to a better performance category.
# * Students with high parental involvement appear more frequently among the improved student group, suggesting that parental support contributes to academic improvement.
# * Improved students are also associated with higher levels of class participation, indicating that active classroom engagement supports better academic outcomes.
# * Higher attendance levels are linked with better academic performance, showing the importance of regular class attendance.
# * Students with stronger motivation levels tend to show better academic results and improvement.
# * Although many students rated Professor Quality as Low, students still showed improvement, suggesting that personal effort, motivation, attendance, and parental support had a stronger impact on student success.
# * Overall, the findings highlight that improving motivation, encouraging active class participation, maintaining good attendance, and increasing parental involvement can contribute significantly to better academic performance and student success.

# %% [markdown]
# # Future Enhancement
# * Real-time academic performance tracking can be implemented to continuously monitor student progress throughout the academic year.
# * Predictive analytics and machine learning models can be developed to identify students who may face academic difficulties and provide early intervention support.
# * Additional factors such as learning behaviour, extracurricular activities, and student feedback can be incorporated to gain deeper insights into academic performance.
# * Personalized academic recommendations can be generated to help students improve study habits, attendance, and overall performance.
# * Faculty and institution-level performance monitoring modules can be added to support data-driven educational planning and policy development.
# * Advanced interactive dashboards with automated alerts and reporting features can be implemented to improve decision-making for educators and academic administrators.

# %% [markdown]
# # Conclusion
#
# The analysis reveals that student academic performance is shaped by multiple academic and personal factors. Although many students initially belonged to the lower-performing Grade C category, a large number successfully improved to Grade B. The improvement analysis highlights the importance of parental involvement, motivation, attendance, class participation and study habits in supporting academic success. These findings can help educational institutions to identify areas for improvement and develop strategies to enhance student learning outcomes and overall academic performance.
